# %%
from numpy.random import randn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  2.,  5.,  8., 12., 19., 17., 13., 16.,  6.]),
#  array([-2.98381582, -2.50084622, -2.01787662, -1.53490701, -1.05193741,
#         -0.56896781, -0.08599821,  0.39697139,  0.879941  ,  1.3629106 ,
#          1.8458802 ]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 2.,  2.,  2.,  4., 14., 17., 14., 11.,  5.,  9.]),
#  array([-2.79699931, -2.32733031, -1.8576613 , -1.38799229, -0.91832329,
#         -0.44865428,  0.02101473,  0.49068373,  0.96035274,  1.43002175,
#          1.89969076]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True)
# Out:
# (array([0.04141047, 0.04141047, 0.10352618, 0.16564189, 0.24846284,
#         0.3933995 , 0.35198903, 0.26916808, 0.33128379, 0.12423142]),
#  array([-2.98381582, -2.50084622, -2.01787662, -1.53490701, -1.05193741,
#         -0.56896781, -0.08599821,  0.39697139,  0.879941  ,  1.3629106 ,
#          1.8458802 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20)
# Out:
# (array([0.05322898, 0.05322898, 0.        , 0.10645795, 0.        ,
#         0.10645795, 0.05322898, 0.15968693, 0.37260283, 0.37260283,
#         0.47906078, 0.4258318 , 0.37260283, 0.37260283, 0.4258318 ,
#         0.15968693, 0.05322898, 0.2129159 , 0.15968693, 0.31937385]),
#  array([-2.79699931, -2.56216481, -2.32733031, -2.0924958 , -1.8576613 ,
#         -1.6228268 , -1.38799229, -1.15315779, -0.91832329, -0.68348878,
#         -0.44865428, -0.21381978,  0.02101473,  0.25584923,  0.49068373,
#          0.72551824,  0.96035274,  1.19518724,  1.43002175,  1.66485625,
#          1.89969076]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind='hex')
