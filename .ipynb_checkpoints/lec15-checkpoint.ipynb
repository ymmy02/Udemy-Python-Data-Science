# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.   First       NFL  \
# 0     1     Dallas   Cowboys          502   374     6   0.573  1960.000
# 1     2      Green       Bay      Packers   737   562  37.000     0.565
# 2     3    Chicago     Bears          749   579    42   0.562  1920.000
# 3     4      Miami  Dolphins          445   351     4   0.559  1966.000
# 4     5        New   England  Patriots[b]   489   386   9.000     0.558
# 5     6  Minnesota   Vikings          470   390    10   0.546  1961.000
#
#   Season  Total  Games Division
# 0    882    NFC   East      NaN
# 1   1921  1,336    NFC    North
# 2  1,370    NFC  North      NaN
# 3    800    AFC   East      NaN
# 4   1960    884    AFC     East
# 5    870    NFC  North      NaN

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL', 'Season',
#        'Total', 'Games', 'Division'],
#       dtype='object')

# %%
nfl_frame['First']
# Out:
# 0     0.573
# 1    37.000
# 2     0.562
# 3     0.559
# 4     9.000
# 5     0.546
# Name: First, dtype: float64

# %%
nfl_frame.Team
# Out:
# 0       Dallas
# 1        Green
# 2      Chicago
# 3        Miami
# 4          New
# 5    Minnesota
# Name: Team, dtype: object

# %%
nfl_frame[['Team', 'First']]
# Out:
#         Team   First
# 0     Dallas   0.573
# 1      Green  37.000
# 2    Chicago   0.562
# 3      Miami   0.559
# 4        New   9.000
# 5  Minnesota   0.546

# %%
DataFrame(nfl_frame, columns=['Team', 'First'])
# Out:
#         Team   First
# 0     Dallas   0.573
# 1      Green  37.000
# 2    Chicago   0.562
# 3      Miami   0.559
# 4        New   9.000
# 5  Minnesota   0.546

# %%
DataFrame(nfl_frame, columns=['Team', 'First', 'Stadium'])
# Out:
#         Team   First  Stadium
# 0     Dallas   0.573      NaN
# 1      Green  37.000      NaN
# 2    Chicago   0.562      NaN
# 3      Miami   0.559      NaN
# 4        New   9.000      NaN
# 5  Minnesota   0.546      NaN

# %%
nfl_frame.head(3)
# Out:
#    Rank     Team      Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas  Cowboys      502   374     6   0.573  1960.000    882
# 1     2    Green      Bay  Packers   737   562  37.000     0.565   1921
# 2     3  Chicago    Bears      749   579    42   0.562  1920.000  1,370
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,336    NFC    North
# 2    NFC  North      NaN

# %%
nfl_frame.tail(3)
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.  First       NFL Season  \
# 3     4      Miami  Dolphins          445   351     4  0.559  1966.000    800
# 4     5        New   England  Patriots[b]   489   386  9.000     0.558   1960
# 5     6  Minnesota   Vikings          470   390    10  0.546  1961.000    870
#
#   Total  Games Division
# 3   AFC   East      NaN
# 4   884    AFC     East
# 5   NFC  North      NaN

# %%
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             445
# Tied             351
# Pct.               4
# First          0.559
# NFL             1966
# Season           800
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.   First       NFL  \
# 0     1     Dallas   Cowboys          502   374     6   0.573  1960.000
# 1     2      Green       Bay      Packers   737   562  37.000     0.565
# 2     3    Chicago     Bears          749   579    42   0.562  1920.000
# 3     4      Miami  Dolphins          445   351     4   0.559  1966.000
# 4     5        New   England  Patriots[b]   489   386   9.000     0.558
# 5     6  Minnesota   Vikings          470   390    10   0.546  1961.000
#
#   Season  Total  Games Division         Stadium
# 0    882    NFC   East      NaN  Levi's Stadium
# 1   1921  1,336    NFC    North  Levi's Stadium
# 2  1,370    NFC  North      NaN  Levi's Stadium
# 3    800    AFC   East      NaN  Levi's Stadium
# 4   1960    884    AFC     East  Levi's Stadium
# 5    870    NFC  North      NaN  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(6)

# %%
nfl_frame
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.   First       NFL  \
# 0     1     Dallas   Cowboys          502   374     6   0.573  1960.000
# 1     2      Green       Bay      Packers   737   562  37.000     0.565
# 2     3    Chicago     Bears          749   579    42   0.562  1920.000
# 3     4      Miami  Dolphins          445   351     4   0.559  1966.000
# 4     5        New   England  Patriots[b]   489   386   9.000     0.558
# 5     6  Minnesota   Vikings          470   390    10   0.546  1961.000
#
#   Season  Total  Games Division  Stadium
# 0    882    NFC   East      NaN        0
# 1   1921  1,336    NFC    North        1
# 2  1,370    NFC  North      NaN        2
# 3    800    AFC   East      NaN        3
# 4   1960    884    AFC     East        4
# 5    870    NFC  North      NaN        5

# %%
stadiums = Series(["Levi's stadium", "AT&T Stadium"], index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.   First       NFL  \
# 0     1     Dallas   Cowboys          502   374     6   0.573  1960.000
# 1     2      Green       Bay      Packers   737   562  37.000     0.565
# 2     3    Chicago     Bears          749   579    42   0.562  1920.000
# 3     4      Miami  Dolphins          445   351     4   0.559  1966.000
# 4     5        New   England  Patriots[b]   489   386   9.000     0.558
# 5     6  Minnesota   Vikings          470   390    10   0.546  1961.000
#
#   Season  Total  Games Division         Stadium
# 0    882    NFC   East      NaN    AT&T Stadium
# 1   1921  1,336    NFC    North             NaN
# 2  1,370    NFC  North      NaN             NaN
# 3    800    AFC   East      NaN             NaN
# 4   1960    884    AFC     East  Levi's stadium
# 5    870    NFC  North      NaN             NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank       Team       Won         Lost  Tied  Pct.   First       NFL  \
# 0     1     Dallas   Cowboys          502   374     6   0.573  1960.000
# 1     2      Green       Bay      Packers   737   562  37.000     0.565
# 2     3    Chicago     Bears          749   579    42   0.562  1920.000
# 3     4      Miami  Dolphins          445   351     4   0.559  1966.000
# 4     5        New   England  Patriots[b]   489   386   9.000     0.558
# 5     6  Minnesota   Vikings          470   390    10   0.546  1961.000
#
#   Season  Total  Games Division
# 0    882    NFC   East      NaN
# 1   1921  1,336    NFC    North
# 2  1,370    NFC  North      NaN
# 3    800    AFC   East      NaN
# 4   1960    884    AFC     East
# 5    870    NFC  North      NaN

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 388000, 8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 388000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA      388000
# 2  NYC     8400000
