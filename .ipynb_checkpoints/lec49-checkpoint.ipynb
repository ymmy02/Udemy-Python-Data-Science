# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(25)

# %%
sns.rugplot(dataset)

# %%
plt.hist(dataset,alpha=0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)

x_min  = dataset.min() - 2
x_max = dataset.max() + 2
x_axis = np.linspace(x_min, x_max, 100)

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**0.2

kernel_list = []
for data_point in dataset:
    # mean = data_point, variance = bandwidth
    kernel = stats.norm(data_point, bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    kernel = kernel / kernel.max()
    kernel = kernel * 0.4
    plt.plot(x_axis, kernel, color = 'gray', alpha = 0.5)
    
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sum_of_kde = np.sum(kernel_list, axis=0)
fig = plt.plot(x_axis, sum_of_kde, color='indianred')
sns.rugplot(dataset)
plt.yticks([])
plt.suptitle('Sum of the Basis Functions')

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset, color='black')
for bw in np.arange(0.5, 2, 0.25):
    sns.kdeplot(dataset, bw=bw, label=bw)

# %%
kernel_options = ["biw", "cos", "epa", "gau", "tri", "triw"]

for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern)

# %%
sns.kdeplot(dataset, vertical=True)

# %%
plt.hist(dataset, cumulative=True)
# Out:
# (array([ 4.,  6., 12., 17., 18., 23., 24., 24., 24., 25.]),
#  array([-1.56659553, -1.08746385, -0.60833217, -0.1292005 ,  0.34993118,
#          0.82906286,  1.30819454,  1.78732621,  2.26645789,  2.74558957,
#          3.22472125]),
#  <a list of 10 Patch objects>)

# %%
sns.kdeplot(dataset, cumulative=True)

# %%
mean=[0,0]
cov=[[1,0], [0, 100]]
dataset2 = np.random.multivariate_normal(mean, cov, 1000)

# %%
dframe = pd.DataFrame(dataset2, columns=['X', 'Y'])
sns.kdeplot(dframe)
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(dframe.X, dframe.Y, shade=True)

# %%
sns.kdeplot(dframe, bw=1)
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(dframe, bw='silverman')
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.jointplot('X', 'Y', dframe, kind='kde')
